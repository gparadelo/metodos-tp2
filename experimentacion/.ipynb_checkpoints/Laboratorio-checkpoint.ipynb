# %%
import numpy as np
import os
import glob
import ntpath
import pandas as pd
import sys
sys.path.append('/usr/local/lib/python2.7/dist-packages')
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
import random
from PIL import Image
import glob

def capitalize(s):
    return s[:1].upper() + s[1:]

# %%
# !cd ./data/ && rm *.csv
# Out:
# rm: cannot remove '*.csv': No such file or directory

# %% [markdown]
# # Creamos los folds

# %%
images='ImagenesCaras'

def writeTrainingSetFold(name, startTest,finishTest):
    file_obj  = open("./training/training-fold-" +name + ".txt", "w") 
    for j in range(1,42):    
        for i in range(1,11): 
            if i < startTest or i >= finishTest:
                file_obj.write("../"+images+"/s"+str(j)+"/"+str(i)+".pgm, "+str(j)+",\n")
    file_obj.close()
    
def writeSmallTrainingSetFold(name, startTest,finishTest, quantity):
    file_obj  = open("./training/small-"+str(quantity)+"-training-fold-" +name + ".txt", "w") 
    for j in range(1,42):    
        q = 0
        for i in range(1,11): 
            if (i < startTest or i >= finishTest) and quantity >= q:
                file_obj.write("../"+images+"/s"+str(j)+"/"+str(i)+".pgm, "+str(j)+",\n")
                q = q+1
    file_obj.close()

def writeTestingSetFold(name,startTest,finishTest):
    file_obj  = open("./testing/testing-fold-" +name + ".txt", "w") 
    for j in range(1,42):    
        for i in range(1,11): 
            if i >= startTest and i < finishTest:
                file_obj.write("../"+images+"/s"+str(j)+"/"+str(i)+".pgm, "+str(j)+",\n")
    file_obj.close()

# %%
k = 5
imagesPerClass = 10
foldSize = 10/5

for i in range(1,11,2):
    j = int(i / 2)
    writeTrainingSetFold(str(j),i,i+2)
    writeTestingSetFold(str(j),i,i+2)    
    for numImgs in range(1,imagesPerClass - 1):
        writeSmallTrainingSetFold(str(j),i,i+2, numImgs)

# %%
! ls
# Out:
# data  graphs  Laboratorio.ipynb  testing  training

# %% [markdown]
# # Borramos la experimentacion previa:

# %%
! cd ./data && ls && rm *.csv
# Out:
# rm: cannot remove '*.csv': No such file or directory

# %%
def refreshResults(i):
    filename = "./data/metrics-"+i+".csv"
    f = open(filename,"w+")
    f.write("k;alpha;averageAccurracy;averagePrecision;averageRecall;averageF1\n")
    f.close()
    
    
for i in range(0,5):
    refreshResults(str(i))
    refreshResults(str(i)+"-knn")

# %% [markdown]
# # Experimentamos solo kNN

# %%
for i in range(0,5):
    for k in range(1,40,3):
        j = str(i) + "-knn"
        training = "../experimentacion/training/training-fold-"+str(i)+".txt"
        testing = "../experimentacion/testing/testing-fold-"+str(i)+".txt"
        metrics = "../experimentacion/data/metrics-"+j+".csv"
        output = "../experimentacion/data/output-"+j+".csv"
        time = "../experimentacion/data/time-"+j+".csv"
        ! ../cmake-build-debug/caralibro -i  $training -q $testing -m 0 -o $output -metrics $metrics -k $k -time $time
        print("Done fold: "+str(i)+", neighbours:"+str(k)+"")
# Out:
# Done fold: 0, neighbours:1
# Done fold: 0, neighbours:4
# Done fold: 0, neighbours:7
# Done fold: 0, neighbours:10
# Done fold: 0, neighbours:13
# Done fold: 0, neighbours:16
# Done fold: 0, neighbours:19
# Done fold: 0, neighbours:22
# Done fold: 0, neighbours:25
# Done fold: 0, neighbours:28
# Done fold: 0, neighbours:31
# Done fold: 0, neighbours:34
# Done fold: 0, neighbours:37
# Done fold: 1, neighbours:1
# Done fold: 1, neighbours:4
# Done fold: 1, neighbours:7
# Done fold: 1, neighbours:10
# Done fold: 1, neighbours:13
# Done fold: 1, neighbours:16
# Done fold: 1, neighbours:19
# Done fold: 1, neighbours:22
# Done fold: 1, neighbours:25
# Done fold: 1, neighbours:28
# Done fold: 1, neighbours:31
# Done fold: 1, neighbours:34
# Done fold: 1, neighbours:37
# Done fold: 2, neighbours:1
# Done fold: 2, neighbours:4
# Done fold: 2, neighbours:7
# Done fold: 2, neighbours:10
# Done fold: 2, neighbours:13
# Done fold: 2, neighbours:16
# Done fold: 2, neighbours:19
# Done fold: 2, neighbours:22
# Done fold: 2, neighbours:25
# Done fold: 2, neighbours:28
# Done fold: 2, neighbours:31
# Done fold: 2, neighbours:34
# Done fold: 2, neighbours:37
# Done fold: 3, neighbours:1
# Done fold: 3, neighbours:4
# Done fold: 3, neighbours:7
# Done fold: 3, neighbours:10
# Done fold: 3, neighbours:13
# Done fold: 3, neighbours:16
# Done fold: 3, neighbours:19
# Done fold: 3, neighbours:22
# Done fold: 3, neighbours:25
# Done fold: 3, neighbours:28
# Done fold: 3, neighbours:31
# Done fold: 3, neighbours:34
# Done fold: 3, neighbours:37
# Done fold: 4, neighbours:1
# Done fold: 4, neighbours:4
# Done fold: 4, neighbours:7
# Done fold: 4, neighbours:10
# Done fold: 4, neighbours:13
# Done fold: 4, neighbours:16
# Done fold: 4, neighbours:19
# Done fold: 4, neighbours:22
# Done fold: 4, neighbours:25
# Done fold: 4, neighbours:28
# Done fold: 4, neighbours:31
# Done fold: 4, neighbours:34
# Done fold: 4, neighbours:37

# %%
simpleframes = [ pd.read_csv("./data/metrics-"+str(i)+"-knn.csv", delimiter=";") for i in range(0,5) ]
simpleresult = pd.concat(simpleframes)

resultgrouped = simpleresult.groupby(["k"]).mean() 
resultgrouped
# Out:
#     alpha  averageAccurracy  averagePrecision  averageRecall  averageF1
# k
# 1      15          0.998691          0.980488       0.973171   0.971707
# 4      15          0.998215          0.974797       0.963415   0.961138
# 7      15          0.994765          0.930894       0.892683   0.876748
# 10     15          0.992029          0.897398       0.836585   0.819071
# 13     15          0.990125          0.872521       0.797561   0.768200
# 16     15          0.987864          0.839350       0.751220   0.735424
# 19     15          0.987151          0.838548       0.736585   0.716709
# 22     15          0.986437          0.829117       0.721951   0.691367
# 25     15          0.986318          0.826841       0.719512   0.695687
# 28     15          0.985366          0.819268       0.700000   0.660650
# 31     15          0.985366          0.822938       0.700000   0.663724
# 34     15          0.984890          0.817329       0.690244   0.652586
# 37     15          0.985128          0.818374       0.695122   0.655459

# %%
def plotMetric(df,xMetric, metric,extraTitle, save):
    columns = [column for column in df.columns if column == metric or column == xMetric]
    newdf = df[columns]    
    ax = newdf.plot()
    ax.set_ylabel("")
    ax.set_xlabel("Valor de: "+ xMetric)
    title = capitalize(metric)+" en funcion de: " +capitalize(xMetric)+" media de analisis 5-Fold "+extraTitle
    plt.title(title)
    if(save):
        plt.savefig("./graphs/"+title)
    else:        
        plt.show()

# %%
for metricToMeasure in ["averageAccurracy","averagePrecision","averageRecall","averageF1"]:
    plotMetric(resultgrouped,"k" , metricToMeasure, "para knn Sin PCA", True)

# %% [markdown]
# # Experimentamos con PCA

# %%
for i in range(0,5):
    for alpha in range(1,329,47):
        for k in range(1,40,3):
            training = "../experimentacion/training/training-fold-"+str(i)+".txt"
            testing = "../experimentacion/testing/testing-fold-"+str(i)+".txt"
            metrics = "../experimentacion/data/metrics-"+str(i)+".csv"
            output = "../experimentacion/data/output-"+str(i)+".csv"
            time = "../experimentacion/data/time-"+str(i)+".csv"
            ! ../cmake-build-debug/caralibro -i  $training -q $testing -m 1 -o $output -metrics $metrics -k $k -alpha $alpha -time $time
            print("Done k: "+str(i)+" alpha: "+str(alpha)+", neighbours:"+str(k)+"")
# Out:
# Done k: 0 alpha: 1, neighbours:1
# Done k: 0 alpha: 1, neighbours:4
# Done k: 0 alpha: 1, neighbours:7
# Done k: 0 alpha: 1, neighbours:10
# Done k: 0 alpha: 1, neighbours:13
# Done k: 0 alpha: 1, neighbours:16
# Done k: 0 alpha: 1, neighbours:19
# Done k: 0 alpha: 1, neighbours:22
# Done k: 0 alpha: 1, neighbours:25
# Done k: 0 alpha: 1, neighbours:28
# Done k: 0 alpha: 1, neighbours:31
# Done k: 0 alpha: 1, neighbours:34
# Done k: 0 alpha: 1, neighbours:37
# Done k: 0 alpha: 48, neighbours:1
# Done k: 0 alpha: 48, neighbours:4
# Done k: 0 alpha: 48, neighbours:7
# Done k: 0 alpha: 48, neighbours:10
# Done k: 0 alpha: 48, neighbours:13
# Done k: 0 alpha: 48, neighbours:16
# Done k: 0 alpha: 48, neighbours:19
# Done k: 0 alpha: 48, neighbours:22
# Done k: 0 alpha: 48, neighbours:25
# Done k: 0 alpha: 48, neighbours:28
# Done k: 0 alpha: 48, neighbours:31
# Done k: 0 alpha: 48, neighbours:34
# Done k: 0 alpha: 48, neighbours:37
# Done k: 0 alpha: 95, neighbours:1
# Done k: 0 alpha: 95, neighbours:4
# Done k: 0 alpha: 95, neighbours:7
# Done k: 0 alpha: 95, neighbours:10
# Done k: 0 alpha: 95, neighbours:13
# Done k: 0 alpha: 95, neighbours:16
# Done k: 0 alpha: 95, neighbours:19
# Done k: 0 alpha: 95, neighbours:22
# Done k: 0 alpha: 95, neighbours:25
# Done k: 0 alpha: 95, neighbours:28
# Done k: 0 alpha: 95, neighbours:31
# Done k: 0 alpha: 95, neighbours:34
# Done k: 0 alpha: 95, neighbours:37
# Done k: 0 alpha: 142, neighbours:1
# Done k: 0 alpha: 142, neighbours:4
# Done k: 0 alpha: 142, neighbours:7
# Done k: 0 alpha: 142, neighbours:10
# Done k: 0 alpha: 142, neighbours:13
# Done k: 0 alpha: 142, neighbours:16
# Done k: 0 alpha: 142, neighbours:19
# Done k: 0 alpha: 142, neighbours:22
# Done k: 0 alpha: 142, neighbours:25
# Done k: 0 alpha: 142, neighbours:28
# Done k: 0 alpha: 142, neighbours:31
# Done k: 0 alpha: 142, neighbours:34
# Done k: 0 alpha: 142, neighbours:37
# Done k: 0 alpha: 189, neighbours:1
# Done k: 0 alpha: 189, neighbours:4
# Done k: 0 alpha: 189, neighbours:7
# Done k: 0 alpha: 189, neighbours:10
# Done k: 0 alpha: 189, neighbours:13
# Done k: 0 alpha: 189, neighbours:16
# Done k: 0 alpha: 189, neighbours:19
# Done k: 0 alpha: 189, neighbours:22
# Done k: 0 alpha: 189, neighbours:25
# Done k: 0 alpha: 189, neighbours:28
# Done k: 0 alpha: 189, neighbours:31
# Done k: 0 alpha: 189, neighbours:34
# Done k: 0 alpha: 189, neighbours:37
# Done k: 0 alpha: 236, neighbours:1
# Done k: 0 alpha: 236, neighbours:4
# Done k: 0 alpha: 236, neighbours:7
# Done k: 0 alpha: 236, neighbours:10
# Done k: 0 alpha: 236, neighbours:13
# Done k: 0 alpha: 236, neighbours:16
# Done k: 0 alpha: 236, neighbours:19
# Done k: 0 alpha: 236, neighbours:22
# Done k: 0 alpha: 236, neighbours:25
# Done k: 0 alpha: 236, neighbours:28
# Done k: 0 alpha: 236, neighbours:31
# Done k: 0 alpha: 236, neighbours:34
# Done k: 0 alpha: 236, neighbours:37
# Done k: 0 alpha: 283, neighbours:1
# Done k: 0 alpha: 283, neighbours:4
# Done k: 0 alpha: 283, neighbours:7
# Done k: 0 alpha: 283, neighbours:10
# Done k: 0 alpha: 283, neighbours:13
# Done k: 0 alpha: 283, neighbours:16
# Done k: 0 alpha: 283, neighbours:19
# Done k: 0 alpha: 283, neighbours:22
# Done k: 0 alpha: 283, neighbours:25
# Done k: 0 alpha: 283, neighbours:28
# Done k: 0 alpha: 283, neighbours:31
# Done k: 0 alpha: 283, neighbours:34
# root of the eigenvalue that should match the tests: 1680.68
# root of the eigenvalue that should match the tests: 1450.65
# root of the eigenvalue that should match the tests: 1035.51
# root of the eigenvalue that should match the tests: 968.081
# root of the eigenvalue that should match the tests: 898.443
# root of the eigenvalue that should match the tests: 731.605
# root of the eigenvalue that should match the tests: 638.582
# root of the eigenvalue that should match the tests: 619.805
# root of the eigenvalue that should match the tests: 573.867
# root of the eigenvalue that should match the tests: 539.898
# root of the eigenvalue that should match the tests: 497.884
# root of the eigenvalue that should match the tests: 470.609
# root of the eigenvalue that should match the tests: 436.907
# root of the eigenvalue that should match the tests: 413.527
# root of the eigenvalue that should match the tests: 400.153
# root of the eigenvalue that should match the tests: 391.62
# root of the eigenvalue that should match the tests: 375.098
# root of the eigenvalue that should match the tests: 367.407
# root of the eigenvalue that should match the tests: 357.818
# root of the eigenvalue that should match the tests: 333.721
# root of the eigenvalue that should match the tests: 330.363
# root of the eigenvalue that should match the tests: 323.674
# root of the eigenvalue that should match the tests: 315.481
# root of the eigenvalue that should match the tests: 306.557
# root of the eigenvalue that should match the tests: 298.532
# root of the eigenvalue that should match the tests: 288.152
# root of the eigenvalue that should match the tests: 280.637
# root of the eigenvalue that should match the tests: 278.69
# root of the eigenvalue that should match the tests: 276.956
# root of the eigenvalue that should match the tests: 271.013
# root of the eigenvalue that should match the tests: 267.337
# root of the eigenvalue that should match the tests: 261.887
# root of the eigenvalue that should match the tests: 262.01
# root of the eigenvalue that should match the tests: 253.683
# root of the eigenvalue that should match the tests: 251.201
# root of the eigenvalue that should match the tests: 242.549
# root of the eigenvalue that should match the tests: 237.408
# root of the eigenvalue that should match the tests: 236.81
# root of the eigenvalue that should match the tests: 229.645
# root of the eigenvalue that should match the tests: 227.733
# root of the eigenvalue that should match the tests: 219.316
# root of the eigenvalue that should match the tests: 217.971
# root of the eigenvalue that should match the tests: 217.425
# root of the eigenvalue that should match the tests: 213.59
# root of the eigenvalue that should match the tests: 210.322
# root of the eigenvalue that should match the tests: 208.597
# root of the eigenvalue that should match the tests: 207.124
# root of the eigenvalue that should match the tests: 202.907
# root of the eigenvalue that should match the tests: 200.473
# root of the eigenvalue that should match the tests: 197.367
# root of the eigenvalue that should match the tests: 195.439
# root of the eigenvalue that should match the tests: 192.658
# root of the eigenvalue that should match the tests: 192.195
# root of the eigenvalue that should match the tests: 191.655
# root of the eigenvalue that should match the tests: 187.212
# root of the eigenvalue that should match the tests: 185.908
# root of the eigenvalue that should match the tests: 184.885
# root of the eigenvalue that should match the tests: 181.912
# root of the eigenvalue that should match the tests: 180.784
# root of the eigenvalue that should match the tests: 177.718
# root of the eigenvalue that should match the tests: 178.124
# root of the eigenvalue that should match the tests: 175.986
# root of the eigenvalue that should match the tests: 173.075
# root of the eigenvalue that should match the tests: 172.197
# root of the eigenvalue that should match the tests: 168.98
# root of the eigenvalue that should match the tests: 167.096
# root of the eigenvalue that should match the tests: 164.1
# root of the eigenvalue that should match the tests: 163.779
# root of the eigenvalue that should match the tests: 159.89
# root of the eigenvalue that should match the tests: 158.431
# root of the eigenvalue that should match the tests: 157.902
# root of the eigenvalue that should match the tests: 157.17
# root of the eigenvalue that should match the tests: 156.705
# root of the eigenvalue that should match the tests: 155.971
# root of the eigenvalue that should match the tests: 154.695
# root of the eigenvalue that should match the tests: 153.295
# root of the eigenvalue that should match the tests: 151.381
# root of the eigenvalue that should match the tests: 151.891
# root of the eigenvalue that should match the tests: 149.806
# root of the eigenvalue that should match the tests: 149.892
# root of the eigenvalue that should match the tests: 147.849
# root of the eigenvalue that should match the tests: 146.504
# root of the eigenvalue that should match the tests: 145.304
# root of the eigenvalue that should match the tests: 145.246
# root of the eigenvalue that should match the tests: 143.174
# root of the eigenvalue that should match the tests: 142.61
# root of the eigenvalue that should match the tests: 142.454
# root of the eigenvalue that should match the tests: 141.825
# root of the eigenvalue that should match the tests: 140.377
# root of the eigenvalue that should match the tests: 138.158
# root of the eigenvalue that should match the tests: 137.43
# root of the eigenvalue that should match the tests: 136.681
# root of the eigenvalue that should match the tests: 136.07
# root of the eigenvalue that should match the tests: 135.717
# root of the eigenvalue that should match the tests: 134.125
# root of the eigenvalue that should match the tests: 133.408
# root of the eigenvalue that should match the tests: 132.775
# root of the eigenvalue that should match the tests: 132.307
# root of the eigenvalue that should match the tests: 132.057
# root of the eigenvalue that should match the tests: 130.976
# root of the eigenvalue that should match the tests: 130.496
# root of the eigenvalue that should match the tests: 129.439
# root of the eigenvalue that should match the tests: 128.465
# root of the eigenvalue that should match the tests: 126.716
# root of the eigenvalue that should match the tests: 126.729
# root of the eigenvalue that should match the tests: 125.339
# root of the eigenvalue that should match the tests: 125.039
# root of the eigenvalue that should match the tests: 124.935
# root of the eigenvalue that should match the tests: 124.207
# root of the eigenvalue that should match the tests: 123.173
# root of the eigenvalue that should match the tests: 122.006
# root of the eigenvalue that should match the tests: 121.942
# root of the eigenvalue that should match the tests: 120.801
# root of the eigenvalue that should match the tests: 120.446
# root of the eigenvalue that should match the tests: 119.845
# root of the eigenvalue that should match the tests: 119.324
# root of the eigenvalue that should match the tests: 118.668
# root of the eigenvalue that should match the tests: 117.908
# root of the eigenvalue that should match the tests: 118.245
# root of the eigenvalue that should match the tests: 117.249
# root of the eigenvalue that should match the tests: 116.447
# root of the eigenvalue that should match the tests: 116.092
# root of the eigenvalue that should match the tests: 115.332
# root of the eigenvalue that should match the tests: 114.771
# root of the eigenvalue that should match the tests: 113.804
# root of the eigenvalue that should match the tests: 113.516
# root of the eigenvalue that should match the tests: 113.647
# root of the eigenvalue that should match the tests: 112.982
# root of the eigenvalue that should match the tests: 111.464
# root of the eigenvalue that should match the tests: 111.777
# root of the eigenvalue that should match the tests: 110.045
# root of the eigenvalue that should match the tests: 110.439
# root of the eigenvalue that should match the tests: 109.366
# root of the eigenvalue that should match the tests: 109.188
# root of the eigenvalue that should match the tests: 109.093
# root of the eigenvalue that should match the tests: 107.959
# root of the eigenvalue that should match the tests: 108.665
# root of the eigenvalue that should match the tests: 107.819
# root of the eigenvalue that should match the tests: 106.848
# root of the eigenvalue that should match the tests: 106.276
# root of the eigenvalue that should match the tests: 105.389
# root of the eigenvalue that should match the tests: 104.654
# root of the eigenvalue that should match the tests: 104.509
# root of the eigenvalue that should match the tests: 104.384
# root of the eigenvalue that should match the tests: 103.856
# root of the eigenvalue that should match the tests: 103.211
# root of the eigenvalue that should match the tests: 103.521
# root of the eigenvalue that should match the tests: 102.657
# root of the eigenvalue that should match the tests: 102.192
# root of the eigenvalue that should match the tests: 101.498
# root of the eigenvalue that should match the tests: 101.7
# root of the eigenvalue that should match the tests: 101.524
# root of the eigenvalue that should match the tests: 101.044
# root of the eigenvalue that should match the tests: 99.8709
# root of the eigenvalue that should match the tests: 98.9997
# root of the eigenvalue that should match the tests: 99.2216
# root of the eigenvalue that should match the tests: 98.7661
# root of the eigenvalue that should match the tests: 97.923
# root of the eigenvalue that should match the tests: 97.9868
# root of the eigenvalue that should match the tests: 97.6458
# root of the eigenvalue that should match the tests: 96.9803
# root of the eigenvalue that should match the tests: 96.6382
# root of the eigenvalue that should match the tests: 96.4804
# root of the eigenvalue that should match the tests: 96.14
# root of the eigenvalue that should match the tests: 95.4639
# root of the eigenvalue that should match the tests: 95.2628
# root of the eigenvalue that should match the tests: 94.7092
# root of the eigenvalue that should match the tests: 94.4174
# root of the eigenvalue that should match the tests: 94.0994
# root of the eigenvalue that should match the tests: 93.4221
# root of the eigenvalue that should match the tests: 93.073
# root of the eigenvalue that should match the tests: 92.7836
# root of the eigenvalue that should match the tests: 92.1975
# root of the eigenvalue that should match the tests: 92.1041
# root of the eigenvalue that should match the tests: 91.8325
# root of the eigenvalue that should match the tests: 91.2485
# root of the eigenvalue that should match the tests: 90.8157
# root of the eigenvalue that should match the tests: 90.8525
# root of the eigenvalue that should match the tests: 89.9977
# root of the eigenvalue that should match the tests: 90.1996
# root of the eigenvalue that should match the tests: 89.3265
# root of the eigenvalue that should match the tests: 89.5172
# root of the eigenvalue that should match the tests: 88.7036
# root of the eigenvalue that should match the tests: 88.5358
# root of the eigenvalue that should match the tests: 88.3407
# root of the eigenvalue that should match the tests: 87.9424
# root of the eigenvalue that should match the tests: 87.076
# root of the eigenvalue that should match the tests: 86.7963
# root of the eigenvalue that should match the tests: 86.7785
# root of the eigenvalue that should match the tests: 86.6085
# root of the eigenvalue that should match the tests: 86.0687
# root of the eigenvalue that should match the tests: 85.7948
# root of the eigenvalue that should match the tests: 85.4932
# root of the eigenvalue that should match the tests: 85.4039
# root of the eigenvalue that should match the tests: 84.7852
# root of the eigenvalue that should match the tests: 84.4772
# root of the eigenvalue that should match the tests: 84.3444
# root of the eigenvalue that should match the tests: 83.9125
# root of the eigenvalue that should match the tests: 83.638
# root of the eigenvalue that should match the tests: 83.0694
# root of the eigenvalue that should match the tests: 82.9784
# root of the eigenvalue that should match the tests: 82.1998
# root of the eigenvalue that should match the tests: 81.8913
# root of the eigenvalue that should match the tests: 81.6077
# root of the eigenvalue that should match the tests: 81.3199
# root of the eigenvalue that should match the tests: 80.9884
# root of the eigenvalue that should match the tests: 80.879
# root of the eigenvalue that should match the tests: 80.017
# root of the eigenvalue that should match the tests: 80.1461
# root of the eigenvalue that should match the tests: 79.8941
# root of the eigenvalue that should match the tests: 79.1275
# root of the eigenvalue that should match the tests: 78.967
# root of the eigenvalue that should match the tests: 78.9476
# root of the eigenvalue that should match the tests: 78.7787
# root of the eigenvalue that should match the tests: 78.2358
# root of the eigenvalue that should match the tests: 77.6877
# root of the eigenvalue that should match the tests: 77.4451
# root of the eigenvalue that should match the tests: 77.3323
# root of the eigenvalue that should match the tests: 77.0797
# root of the eigenvalue that should match the tests: 76.5792
# root of the eigenvalue that should match the tests: 76.4447
# root of the eigenvalue that should match the tests: 75.9391
# root of the eigenvalue that should match the tests: 75.5855
# root of the eigenvalue that should match the tests: 75.645
# root of the eigenvalue that should match the tests: 75.3926
# root of the eigenvalue that should match the tests: 75.3899
# root of the eigenvalue that should match the tests: 74.4307
# root of the eigenvalue that should match the tests: 74.3757
# root of the eigenvalue that should match the tests: 74.2603
# root of the eigenvalue that should match the tests: 73.8176
# root of the eigenvalue that should match the tests: 73.8545
# root of the eigenvalue that should match the tests: 73.3858
# root of the eigenvalue that should match the tests: 73.0136
# root of the eigenvalue that should match the tests: 73.2471
# root of the eigenvalue that should match the tests: 72.4524
# root of the eigenvalue that should match the tests: 72.1165
# root of the eigenvalue that should match the tests: 71.773
# root of the eigenvalue that should match the tests: 72.0312
# root of the eigenvalue that should match the tests: 71.3352
# root of the eigenvalue that should match the tests: 71.2612
# root of the eigenvalue that should match the tests: 70.7709
# root of the eigenvalue that should match the tests: 70.2885
# root of the eigenvalue that should match the tests: 70.2389
# root of the eigenvalue that should match the tests: 70.4104
# root of the eigenvalue that should match the tests: 70.3705
# root of the eigenvalue that should match the tests: 69.6287
# root of the eigenvalue that should match the tests: 69.2619
# root of the eigenvalue that should match the tests: 68.9503
# root of the eigenvalue that should match the tests: 68.9818
# root of the eigenvalue that should match the tests: 68.4933
# root of the eigenvalue that should match the tests: 68.0673
# root of the eigenvalue that should match the tests: 68.0948
# root of the eigenvalue that should match the tests: 67.6743
# root of the eigenvalue that should match the tests: 67.5416
# root of the eigenvalue that should match the tests: 66.9269
# root of the eigenvalue that should match the tests: 66.5095
# root of the eigenvalue that should match the tests: 66.3274
# root of the eigenvalue that should match the tests: 66.3201
# root of the eigenvalue that should match the tests: 66.1167
# root of the eigenvalue that should match the tests: 65.7081
# root of the eigenvalue that should match the tests: 65.5128
# root of the eigenvalue that should match the tests: 65.2873
# root of the eigenvalue that should match the tests: 65.2434
# root of the eigenvalue that should match the tests: 64.4997
# root of the eigenvalue that should match the tests: 64.4325
# root of the eigenvalue that should match the tests: 64.1544
# root of the eigenvalue that should match the tests: 63.597
# root of the eigenvalue that should match the tests: 63.5057
# root of the eigenvalue that should match the tests: 63.622
# root of the eigenvalue that should match the tests: 62.9806
# root of the eigenvalue that should match the tests: 63.1099
# root of the eigenvalue that should match the tests: 62.0762
# root of the eigenvalue that should match the tests: 61.9993
# root of the eigenvalue that should match the tests: 61.9816
# root of the eigenvalue that should match the tests: 61.913
# root of the eigenvalue that should match the tests: 61.128
# root of the eigenvalue that should match the tests: 61.1678
# root of the eigenvalue that should match the tests: 60.5477
# root of the eigenvalue that should match the tests: 60.4605
# root of the eigenvalue that should match the tests: 60.4214
# root of the eigenvalue that should match the tests: 60.4675
# root of the eigenvalue that should match the tests: 59.827
# root of the eigenvalue that should match the tests: 59.886
# Done k: 0 alpha: 283, neighbours:37
# root of the eigenvalue that should match the tests: 1665.91
# Done k: 1 alpha: 1, neighbours:1
# root of the eigenvalue that should match the tests: 1665.91
# Done k: 1 alpha: 1, neighbours:4
# root of the eigenvalue that should match the tests: 1665.91
# Done k: 1 alpha: 1, neighbours:7
# root of the eigenvalue that should match the tests: 1665.91
# Done k: 1 alpha: 1, neighbours:10
# root of the eigenvalue that should match the tests: 1665.91
# Done k: 1 alpha: 1, neighbours:13
# root of the eigenvalue that should match the tests: 1665.91
# Done k: 1 alpha: 1, neighbours:16
# root of the eigenvalue that should match the tests: 1665.91
# Done k: 1 alpha: 1, neighbours:19
# root of the eigenvalue that should match the tests: 1665.91
# Done k: 1 alpha: 1, neighbours:22
# root of the eigenvalue that should match the tests: 1665.91
# Done k: 1 alpha: 1, neighbours:25
# root of the eigenvalue that should match the tests: 1665.91
# Done k: 1 alpha: 1, neighbours:28
# Done k: 1 alpha: 1, neighbours:31
# Done k: 1 alpha: 1, neighbours:34
# Done k: 1 alpha: 1, neighbours:37
# Done k: 1 alpha: 48, neighbours:1
# Done k: 1 alpha: 48, neighbours:4
# Done k: 1 alpha: 48, neighbours:7
# Done k: 1 alpha: 48, neighbours:10
# Done k: 1 alpha: 48, neighbours:13
# Done k: 1 alpha: 48, neighbours:16
# Done k: 1 alpha: 48, neighbours:19
# Done k: 1 alpha: 48, neighbours:22
# Done k: 1 alpha: 48, neighbours:25
# Done k: 1 alpha: 48, neighbours:28
# Done k: 1 alpha: 48, neighbours:31
# Done k: 1 alpha: 48, neighbours:34
# Done k: 1 alpha: 48, neighbours:37
# Done k: 1 alpha: 95, neighbours:1
# Done k: 1 alpha: 95, neighbours:4
# Done k: 1 alpha: 95, neighbours:7
# Done k: 1 alpha: 95, neighbours:10
# Done k: 1 alpha: 95, neighbours:13
# Done k: 1 alpha: 95, neighbours:16
# Done k: 1 alpha: 95, neighbours:19
# Done k: 1 alpha: 95, neighbours:22
# Done k: 1 alpha: 95, neighbours:25
# Done k: 1 alpha: 95, neighbours:28
# Done k: 1 alpha: 95, neighbours:31
# Done k: 1 alpha: 95, neighbours:34
# Done k: 1 alpha: 95, neighbours:37
# Done k: 1 alpha: 142, neighbours:1
# Done k: 1 alpha: 142, neighbours:4
# Done k: 1 alpha: 142, neighbours:7
# Done k: 1 alpha: 142, neighbours:10
# Done k: 1 alpha: 142, neighbours:13
# Done k: 1 alpha: 142, neighbours:16
# Done k: 1 alpha: 142, neighbours:19
# Done k: 1 alpha: 142, neighbours:22
# Done k: 1 alpha: 142, neighbours:25
# Done k: 1 alpha: 142, neighbours:28
# Done k: 1 alpha: 142, neighbours:31
# Done k: 1 alpha: 142, neighbours:34
# Done k: 1 alpha: 142, neighbours:37
# Done k: 1 alpha: 189, neighbours:1
# Done k: 1 alpha: 189, neighbours:4
# Done k: 1 alpha: 189, neighbours:7
# Done k: 1 alpha: 189, neighbours:10
# Done k: 1 alpha: 189, neighbours:13
# Done k: 1 alpha: 189, neighbours:16
# Done k: 1 alpha: 189, neighbours:19
# Done k: 1 alpha: 189, neighbours:22
# Done k: 1 alpha: 189, neighbours:25
# Done k: 1 alpha: 189, neighbours:28
# Done k: 1 alpha: 189, neighbours:31
# Done k: 1 alpha: 189, neighbours:34
# Done k: 1 alpha: 189, neighbours:37
# Done k: 1 alpha: 236, neighbours:1
# Done k: 1 alpha: 236, neighbours:4
# Done k: 1 alpha: 236, neighbours:7
# Done k: 1 alpha: 236, neighbours:10
# Done k: 1 alpha: 236, neighbours:13
# Done k: 1 alpha: 236, neighbours:16
# Done k: 1 alpha: 236, neighbours:19
# Done k: 1 alpha: 236, neighbours:22
# Done k: 1 alpha: 236, neighbours:25
# Done k: 1 alpha: 236, neighbours:28
# Done k: 1 alpha: 236, neighbours:31
# Done k: 1 alpha: 236, neighbours:34
# Done k: 1 alpha: 236, neighbours:37
# Done k: 1 alpha: 283, neighbours:1
# Done k: 1 alpha: 283, neighbours:4
# Done k: 1 alpha: 283, neighbours:7
# Done k: 1 alpha: 283, neighbours:10
# Done k: 1 alpha: 283, neighbours:13
# Done k: 1 alpha: 283, neighbours:16
# Done k: 1 alpha: 283, neighbours:19
# Done k: 1 alpha: 283, neighbours:22
# Done k: 1 alpha: 283, neighbours:25
# Done k: 1 alpha: 283, neighbours:28
# Done k: 1 alpha: 283, neighbours:31
# Done k: 1 alpha: 283, neighbours:34
# Done k: 1 alpha: 283, neighbours:37
# Done k: 2 alpha: 1, neighbours:1
# Done k: 2 alpha: 1, neighbours:4
# Done k: 2 alpha: 1, neighbours:7
# Done k: 2 alpha: 1, neighbours:10
# Done k: 2 alpha: 1, neighbours:13
# Done k: 2 alpha: 1, neighbours:16
# Done k: 2 alpha: 1, neighbours:19
# Done k: 2 alpha: 1, neighbours:22
# Done k: 2 alpha: 1, neighbours:25
# Done k: 2 alpha: 1, neighbours:28
# Done k: 2 alpha: 1, neighbours:31
# Done k: 2 alpha: 1, neighbours:34
# Done k: 2 alpha: 1, neighbours:37
# Done k: 2 alpha: 48, neighbours:1
# Done k: 2 alpha: 48, neighbours:4
# Done k: 2 alpha: 48, neighbours:7
# Done k: 2 alpha: 48, neighbours:10
# Done k: 2 alpha: 48, neighbours:13
# Done k: 2 alpha: 48, neighbours:16
# Done k: 2 alpha: 48, neighbours:19
# Done k: 2 alpha: 48, neighbours:22
# Done k: 2 alpha: 48, neighbours:25
# Done k: 2 alpha: 48, neighbours:28
# Done k: 2 alpha: 48, neighbours:31
# Done k: 2 alpha: 48, neighbours:34
# Done k: 2 alpha: 48, neighbours:37
# Done k: 2 alpha: 95, neighbours:1
# Done k: 2 alpha: 95, neighbours:4
# Done k: 2 alpha: 95, neighbours:7
# Done k: 2 alpha: 95, neighbours:10
# Done k: 2 alpha: 95, neighbours:13
# Done k: 2 alpha: 95, neighbours:16
# Done k: 2 alpha: 95, neighbours:19
# Done k: 2 alpha: 95, neighbours:22
# Done k: 2 alpha: 95, neighbours:25
# Done k: 2 alpha: 95, neighbours:28
# Done k: 2 alpha: 95, neighbours:31
# Done k: 2 alpha: 95, neighbours:34
# Done k: 2 alpha: 95, neighbours:37
# Done k: 2 alpha: 142, neighbours:1
# Done k: 2 alpha: 142, neighbours:4
# Done k: 2 alpha: 142, neighbours:7
# Done k: 2 alpha: 142, neighbours:10
# Done k: 2 alpha: 142, neighbours:13
# Done k: 2 alpha: 142, neighbours:16
# Done k: 2 alpha: 142, neighbours:19
# Done k: 2 alpha: 142, neighbours:22
# Done k: 2 alpha: 142, neighbours:25
# Done k: 2 alpha: 142, neighbours:28
# Done k: 2 alpha: 142, neighbours:31
# Done k: 2 alpha: 142, neighbours:34
# Done k: 2 alpha: 142, neighbours:37
# Done k: 2 alpha: 189, neighbours:1
# Done k: 2 alpha: 189, neighbours:4
# Done k: 2 alpha: 189, neighbours:7
# Done k: 2 alpha: 189, neighbours:10
# Done k: 2 alpha: 189, neighbours:13
# Done k: 2 alpha: 189, neighbours:16
# Done k: 2 alpha: 189, neighbours:19
# Done k: 2 alpha: 189, neighbours:22
# Done k: 2 alpha: 189, neighbours:25
# Done k: 2 alpha: 189, neighbours:28
# Done k: 2 alpha: 189, neighbours:31
# Done k: 2 alpha: 189, neighbours:34
# Done k: 2 alpha: 189, neighbours:37
# Done k: 2 alpha: 236, neighbours:1
# Done k: 2 alpha: 236, neighbours:4
# Done k: 2 alpha: 236, neighbours:7
# Done k: 2 alpha: 236, neighbours:10
# Done k: 2 alpha: 236, neighbours:13
# Done k: 2 alpha: 236, neighbours:16
# Done k: 2 alpha: 236, neighbours:19
# Done k: 2 alpha: 236, neighbours:22
# Done k: 2 alpha: 236, neighbours:25
# Done k: 2 alpha: 236, neighbours:28
# Done k: 2 alpha: 236, neighbours:31
# Done k: 2 alpha: 236, neighbours:34
# Done k: 2 alpha: 236, neighbours:37
# Done k: 2 alpha: 283, neighbours:1
# Done k: 2 alpha: 283, neighbours:4
# Done k: 2 alpha: 283, neighbours:7
# Done k: 2 alpha: 283, neighbours:10
# Done k: 2 alpha: 283, neighbours:13
# Done k: 2 alpha: 283, neighbours:16
# Done k: 2 alpha: 283, neighbours:19
# Done k: 2 alpha: 283, neighbours:22
# Done k: 2 alpha: 283, neighbours:25
# Done k: 2 alpha: 283, neighbours:28
# Done k: 2 alpha: 283, neighbours:31
# Done k: 2 alpha: 283, neighbours:34
# Done k: 2 alpha: 283, neighbours:37
# Done k: 3 alpha: 1, neighbours:1
# Done k: 3 alpha: 1, neighbours:4
# Done k: 3 alpha: 1, neighbours:7
# Done k: 3 alpha: 1, neighbours:10
# Done k: 3 alpha: 1, neighbours:13
# Done k: 3 alpha: 1, neighbours:16
# Done k: 3 alpha: 1, neighbours:19
# Done k: 3 alpha: 1, neighbours:22
# Done k: 3 alpha: 1, neighbours:25
# Done k: 3 alpha: 1, neighbours:28
# Done k: 3 alpha: 1, neighbours:31
# Done k: 3 alpha: 1, neighbours:34
# Done k: 3 alpha: 1, neighbours:37
# Done k: 3 alpha: 48, neighbours:1
# Done k: 3 alpha: 48, neighbours:4
# Done k: 3 alpha: 48, neighbours:7
# Done k: 3 alpha: 48, neighbours:10
# Done k: 3 alpha: 48, neighbours:13
# Done k: 3 alpha: 48, neighbours:16
# Done k: 3 alpha: 48, neighbours:19
# Done k: 3 alpha: 48, neighbours:22
# Done k: 3 alpha: 48, neighbours:25
# Done k: 3 alpha: 48, neighbours:28
# Done k: 3 alpha: 48, neighbours:31
# Done k: 3 alpha: 48, neighbours:34
# Done k: 3 alpha: 48, neighbours:37
# Done k: 3 alpha: 95, neighbours:1
# Done k: 3 alpha: 95, neighbours:4
# Done k: 3 alpha: 95, neighbours:7
# Done k: 3 alpha: 95, neighbours:10
# Done k: 3 alpha: 95, neighbours:13
# Done k: 3 alpha: 95, neighbours:16
# Done k: 3 alpha: 95, neighbours:19
# Done k: 3 alpha: 95, neighbours:22
# Done k: 3 alpha: 95, neighbours:25
# Done k: 3 alpha: 95, neighbours:28
# Done k: 3 alpha: 95, neighbours:31
# Done k: 3 alpha: 95, neighbours:34
# Done k: 3 alpha: 95, neighbours:37
# Done k: 3 alpha: 142, neighbours:1
# Done k: 3 alpha: 142, neighbours:4
# Done k: 3 alpha: 142, neighbours:7
# Done k: 3 alpha: 142, neighbours:10
# Done k: 3 alpha: 142, neighbours:13
# Done k: 3 alpha: 142, neighbours:16
# Done k: 3 alpha: 142, neighbours:19
# Done k: 3 alpha: 142, neighbours:22
# Done k: 3 alpha: 142, neighbours:25
# Done k: 3 alpha: 142, neighbours:28
# Done k: 3 alpha: 142, neighbours:31
# Done k: 3 alpha: 142, neighbours:34
# Done k: 3 alpha: 142, neighbours:37
# Done k: 3 alpha: 189, neighbours:1
# Done k: 3 alpha: 189, neighbours:4
# Done k: 3 alpha: 189, neighbours:7
# Done k: 3 alpha: 189, neighbours:10
# Done k: 3 alpha: 189, neighbours:13
# Done k: 3 alpha: 189, neighbours:16
# Done k: 3 alpha: 189, neighbours:19
# Done k: 3 alpha: 189, neighbours:22
# Done k: 3 alpha: 189, neighbours:25
# Done k: 3 alpha: 189, neighbours:28
# Done k: 3 alpha: 189, neighbours:31
# Done k: 3 alpha: 189, neighbours:34
# Done k: 3 alpha: 189, neighbours:37
# Done k: 3 alpha: 236, neighbours:1
# Done k: 3 alpha: 236, neighbours:4
# Done k: 3 alpha: 236, neighbours:7
# Done k: 3 alpha: 236, neighbours:10
# Done k: 3 alpha: 236, neighbours:13
# Done k: 3 alpha: 236, neighbours:16
# Done k: 3 alpha: 236, neighbours:19
# Done k: 3 alpha: 236, neighbours:22
# Done k: 3 alpha: 236, neighbours:25
# Done k: 3 alpha: 236, neighbours:28
# Done k: 3 alpha: 236, neighbours:31
# Done k: 3 alpha: 236, neighbours:34
# Done k: 3 alpha: 236, neighbours:37
# Done k: 3 alpha: 283, neighbours:1
# Done k: 3 alpha: 283, neighbours:4
# Done k: 3 alpha: 283, neighbours:7
# Done k: 3 alpha: 283, neighbours:10
# Done k: 3 alpha: 283, neighbours:13
# Done k: 3 alpha: 283, neighbours:16
# Done k: 3 alpha: 283, neighbours:19
# Done k: 3 alpha: 283, neighbours:22
# Done k: 3 alpha: 283, neighbours:25
# Done k: 3 alpha: 283, neighbours:28
# Done k: 3 alpha: 283, neighbours:31
# Done k: 3 alpha: 283, neighbours:34
# Done k: 3 alpha: 283, neighbours:37
# Done k: 4 alpha: 1, neighbours:1
# Done k: 4 alpha: 1, neighbours:4
# Done k: 4 alpha: 1, neighbours:7
# Done k: 4 alpha: 1, neighbours:10
# Done k: 4 alpha: 1, neighbours:13
# Done k: 4 alpha: 1, neighbours:16
# Done k: 4 alpha: 1, neighbours:19
# Done k: 4 alpha: 1, neighbours:22
# Done k: 4 alpha: 1, neighbours:25
# Done k: 4 alpha: 1, neighbours:28
# Done k: 4 alpha: 1, neighbours:31
# Done k: 4 alpha: 1, neighbours:34
# Done k: 4 alpha: 1, neighbours:37
# Done k: 4 alpha: 48, neighbours:1
# Done k: 4 alpha: 48, neighbours:4
# Done k: 4 alpha: 48, neighbours:7
# Done k: 4 alpha: 48, neighbours:10
# Done k: 4 alpha: 48, neighbours:13
# Done k: 4 alpha: 48, neighbours:16
# Done k: 4 alpha: 48, neighbours:19
# Done k: 4 alpha: 48, neighbours:22
# Done k: 4 alpha: 48, neighbours:25
# Done k: 4 alpha: 48, neighbours:28
# Done k: 4 alpha: 48, neighbours:31
# Done k: 4 alpha: 48, neighbours:34
# Done k: 4 alpha: 48, neighbours:37
# Done k: 4 alpha: 95, neighbours:1
# Done k: 4 alpha: 95, neighbours:4
# Done k: 4 alpha: 95, neighbours:7
# Done k: 4 alpha: 95, neighbours:10
# Done k: 4 alpha: 95, neighbours:13
# Done k: 4 alpha: 95, neighbours:16
# Done k: 4 alpha: 95, neighbours:19
# Done k: 4 alpha: 95, neighbours:22
# Done k: 4 alpha: 95, neighbours:25
# Done k: 4 alpha: 95, neighbours:28
# Done k: 4 alpha: 95, neighbours:31
# Done k: 4 alpha: 95, neighbours:34
# Done k: 4 alpha: 95, neighbours:37
# Done k: 4 alpha: 142, neighbours:1
# Done k: 4 alpha: 142, neighbours:4
# Done k: 4 alpha: 142, neighbours:7
# Done k: 4 alpha: 142, neighbours:10
# Done k: 4 alpha: 142, neighbours:13
# Done k: 4 alpha: 142, neighbours:16
# Done k: 4 alpha: 142, neighbours:19
# Done k: 4 alpha: 142, neighbours:22
# Done k: 4 alpha: 142, neighbours:25
# Done k: 4 alpha: 142, neighbours:28
# Done k: 4 alpha: 142, neighbours:31
# Done k: 4 alpha: 142, neighbours:34
# Done k: 4 alpha: 142, neighbours:37
# Done k: 4 alpha: 189, neighbours:1
# Done k: 4 alpha: 189, neighbours:4
# Done k: 4 alpha: 189, neighbours:7
# Done k: 4 alpha: 189, neighbours:10
# Done k: 4 alpha: 189, neighbours:13
# Done k: 4 alpha: 189, neighbours:16
# Done k: 4 alpha: 189, neighbours:19
# Done k: 4 alpha: 189, neighbours:22
# Done k: 4 alpha: 189, neighbours:25
# Done k: 4 alpha: 189, neighbours:28
# Done k: 4 alpha: 189, neighbours:31
# Done k: 4 alpha: 189, neighbours:34
# Done k: 4 alpha: 189, neighbours:37
# Done k: 4 alpha: 236, neighbours:1
# Done k: 4 alpha: 236, neighbours:4
# Done k: 4 alpha: 236, neighbours:7
# Done k: 4 alpha: 236, neighbours:10
# Done k: 4 alpha: 236, neighbours:13
# Done k: 4 alpha: 236, neighbours:16
# Done k: 4 alpha: 236, neighbours:19
# Done k: 4 alpha: 236, neighbours:22
# Done k: 4 alpha: 236, neighbours:25
# Done k: 4 alpha: 236, neighbours:28
# Done k: 4 alpha: 236, neighbours:31
# Done k: 4 alpha: 236, neighbours:34
# Done k: 4 alpha: 236, neighbours:37
# Done k: 4 alpha: 283, neighbours:1
# Done k: 4 alpha: 283, neighbours:4
# Done k: 4 alpha: 283, neighbours:7
# Done k: 4 alpha: 283, neighbours:10
# Done k: 4 alpha: 283, neighbours:13
# Done k: 4 alpha: 283, neighbours:16
# Done k: 4 alpha: 283, neighbours:19
# Done k: 4 alpha: 283, neighbours:22
# Done k: 4 alpha: 283, neighbours:25
# Done k: 4 alpha: 283, neighbours:28
# Done k: 4 alpha: 283, neighbours:31
# Done k: 4 alpha: 283, neighbours:34
# Done k: 4 alpha: 283, neighbours:37

# %% [markdown]
# ## Obtenemos el índice del máximo

# %%
frames = [ pd.read_csv("./data/metrics-"+str(i)+".csv", delimiter=";") for i in range(0,5) ]
pcaresult = pd.concat(frames)
resultgrouped = pcaresult.groupby(["alpha","k"]).mean() 
resultgrouped.loc[:,'averageF1'] *= 2 

resultgrouped.idxmax()
# Out:
# averageAccurracy    (48, 1)
# averagePrecision    (48, 1)
# averageRecall       (48, 1)
# averageF1            (1, 1)
# dtype: object

# %%
for metricToMeasure in ["averageAccurracy","averagePrecision","averageRecall","averageF1"]:
    plotMetric(resultgrouped,"Alpha y K" , metricToMeasure, "para knn Con PCA", True)

# %%
def plotFrame(df,idx):
    for al in range(1,31,5):
        copydf = df[df.alpha == al]
#         columns = [column for column in copydf.columns if column != 'alpha']
        columns = [column for column in copydf.columns if column != 'alpha' and column != 'averagePrecision' and column != 'averageRecall' and column != 'averageF1']
        newdf = copydf[columns]    
        ax = newdf.plot(x="k", logy=False)
        ax.set_ylabel("")
        ax.set_xlabel("Valor de K" )
        title = "Fold: "+str(idx) + ", Alpha: " +str(al)
        plt.title(title)
        plt.show()
#         plt.savefig("./graphs/"+title)

# %%
for idx,frame in enumerate(frames):
    plotFrame(frame,idx)

# %%
resultgrouped = result.groupby(["alpha","k"]).mean()

# %%
resultgrouped

# %% [markdown]
# # Medimos si el tamaño del dataset mejora PCA

# %%
alpha = bestAlpha
k = bestK
for i in range(0,5):
    for numImgs in range(1,imagesPerClass - 1):
    training = "../experimentacion/training/small-"+str(numImgs)+"-training-fold-"+str(i)+".txt"
    testing = "../experimentacion/testing/testing-fold-"+str(i)+".txt"
    metrics = "../experimentacion/data/small-"+str(numImgs)+"-metrics-"+str(i)+".csv"
    output = "../experimentacion/data/small-"+str(numImgs)+"-output-"+str(i)+".csv"
    ! ../cmake-build-debug/caralibro -i  $training -q $testing -m 1 -o $output -metrics $metrics -k $k -alpha $alpha -time $time
    print("Done k: "+str(i)+" alpha: "+str(alpha)+", neighbours:"+str(k)+"")

# %%
for smallSetNumber in (1,imagesPerClass=1):
    frames = [ pd.read_csv("./data/small-"+str(numImgs)+"metrics-"+str(i)+".csv", delimiter=";") for i in range(0,5) ]
    concatframes = pd.concat(frames)
    foldMedia = concatframes.mean()

# %% [markdown]
# # Miremos cuánto tarda entrenar con PCA con Knn

# %%
! cd ./data && ls && rm time.csv
def refreshResults(i):
    filename = "./data/time-"+str(i)+".csv"
    f = open(filename,"w+")
    f.write("mode;k;alpha;Training Time;Evaluation Time\n")
    f.close()
refreshResults(1)
# Out:
# metrics.csv   output.csv     results-1.csv  results-3.csv  results.csv
# output-1.csv  results-0.csv  results-2.csv  results-4.csv  time-1.csv
# rm: cannot remove 'time.csv': No such file or directory

# %%
for alpha in range(1,644,20):
    training = "../experimentacion/training/training-fold-"+str(1)+".txt"
    testing = "../experimentacion/testing/testing-fold-"+str(1)+".txt"
    metrics = "../experimentacion/data/metrics-"+str(1)+".csv"
    output = "../experimentacion/data/output-"+str(1)+".csv"
    time = "../experimentacion/data/time-"+str(1)+".csv"
    ! ../cmake-build-debug/caralibro -i  $training -q $testing -m 1 -o $output -alpha $alpha -time $time

# %%
df = pd.read_csv("./data/time-1.csv", delimiter = ";")
copydf = df
columns = [column for column in copydf.columns if column == 'alpha' or column == 'Training Time']
newdf = copydf[columns]    
ax = newdf.plot(x="alpha", logy=False)
ax.set_ylabel("Segundos")
ax.set_xlabel("Valor de Alpha" )
title = "Tiempo de entrenamiento en función de alpha"
plt.title(title)
plt.show()
plt.savefig("./graphs/"+title)

# %% [markdown]
# # Miremos como aumenta el tiempo de evaluacion en función de los pixels

# %%
df = pd.read_csv("./data/time-1.csv", delimiter = ";")
copydf = df
columns = [column for column in copydf.columns if column == 'alpha' or column == 'Evaluation Time']
newdf = copydf[columns]    
ax = newdf.plot(x="alpha", logy=False)
ax.set_ylabel("Segundos")
ax.set_xlabel("Cantidad de Pixels" )
title = "Tiempo de entrenamiento en función de los pixels observados"
plt.title(title)
plt.show()
plt.savefig("./graphs/"+title)
